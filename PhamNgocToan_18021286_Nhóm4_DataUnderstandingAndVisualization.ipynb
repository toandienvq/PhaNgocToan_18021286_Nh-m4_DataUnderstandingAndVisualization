# %%
import pandas as pd
import numpy as np

# %%
Data = pd.read_csv('Nganhang.csv')
Data
# Out:
#                      customerNumber customerName contactLastName  \
# 1                   elier graphique      Schmitt         Carine
# 112              Signal Gift Stores         King            Jean
# 114           Australian Collectors          Co.        Ferguson
# 119               La Rochelle Gifts      Labrune         Janine
# 121              Baane Mini Imports   Bergulfsen          Jonas
# 357                 GiftsForHim.com    MacKinlay           Wales
# 361                 Kommission Auto      Josephs           Karin
# 362               Gifts4AllAges.com      Yoshido            Juri
# 363    Online Diecast Creations Co.        Young         Dorothy
# 369               Lisboa Souveniers          Inc       Rodriguez
# 376           Precious Collectables          Urs           Braun
# 379      Collectables For Less Inc.       Nelson           Allen
# 381                    Royale Belge     Cartrain        Pascale
# ...

# %%
Data.shape
# Out:
# (49, 13)

# %%
Data.dtypes
# Out:
# customerNumber             object
# customerName               object
# contactLastName            object
# contactFirstName           object
# phone                      object
# addressLine1               object
# addressLine2               object
# city                       object
# state                      object
# postalCode                 object
# country                    object
# salesRepEmployeeNumber    float64
# creditLimit               float64
# dtype: object

# %%
Data.describe
# Out:
# <bound method NDFrame.describe of                      customerNumber customerName contactLastName  \
# 103               Atelier graphique      Schmitt         Carine
# 112              Signal Gift Stores         King            Jean
# 114           Australian Collectors          Co.        Ferguson
# 119               La Rochelle Gifts      Labrune         Janine
# 121              Baane Mini Imports   Bergulfsen          Jonas
# 357                 GiftsForHim.com    MacKinlay           Wales
# 361                 Kommission Auto      Josephs           Karin
# 362               Gifts4AllAges.com      Yoshido            Juri
# 363    Online Diecast Creations Co.        Young         Dorothy
# 369               Lisboa Souveniers          Inc       Rodriguez
# 376           Precious Collectables          Urs           Braun
# 379      Collectables For Less Inc.       Nelson           Allen
# 381                    Royale Belge     Cartrain        Pascale
# ...

# %%
Data.groupby('France')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2477fbf4d35b> in <module>
# ----> 1 Data.groupby('France')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
print(type(customerName))
print(type(country))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7af3dd4d7282> in <module>
# ----> 1 print(type(customerName))
#       2 print(type(country))
#
# NameError: name 'customerName' is not defined

# %%
Data.dtypes
# Out:
# customerNumber             object
# customerName               object
# contactLastName            object
# contactFirstName           object
# phone                      object
# addressLine1               object
# addressLine2               object
# city                       object
# state                      object
# postalCode                 object
# country                    object
# salesRepEmployeeNumber    float64
# creditLimit               float64
# dtype: object

# %%
print(type(city))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-763191b90b45> in <module>
# ----> 1 print(type(city))
#
# NameError: name 'city' is not defined
